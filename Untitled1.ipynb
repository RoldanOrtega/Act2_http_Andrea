# %% [markdown]
# <a href="https://colab.research.google.com/github/RoldanOrtega/Act2_http_Andrea/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# declarando variables
p=140 # precio de la falda
D=30 # descuento en porcentaje
pd=p*D/100 # precio descuento
tp=p-pd # precio final
# visualizamdo resultados
print("Ramirez Alvarez Azul No control 25308051280441")
print("el precio de la falda es :"+ str (p))
print("el descuento es :"+ str (D))
print("el precio de descuento es :"+ str (pd))
print("el precio final es :"+ str (tp))
# Out:
# Ramirez Alvarez Azul No control 25308051280441
# el precio de la falda es :140
# el descuento es :30
# el precio de descuento es :42.0
# el precio final es :98.0
